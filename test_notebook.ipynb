# %% [markdown]
# # Markdown

# %% [markdown]
# # Heading 1

# %% [markdown]
# ## Heading 2

# %% [markdown]
# ### Heading 3

# %% [markdown]
# #### Heading 4

# %% [markdown]
# ##### Heading 5

# %% [markdown]
# In markdown I can *italicize words or __bold__ them
#
# ___
#
#
# <center> I can also center text
#
# ___
#
# I can make a link [I'm an inline-style link](https://www.google.com)
#
# ___
#
# Or add an image.
#
# Corgi:
# ![alt text](https://s-media-cache-ak0.pinimg.com/736x/bf/b6/19/bfb6192a36bb33728209ac1040f2f574.jpg "Logo Title Text 1")

# %% [markdown]
# # Code Examples

# %% [markdown]
# The cells below dont need to run, their purpose is to show you the general structure and color used in typical code.

# %%
import sys
import os

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

os.chdir('/Users/kateme')
from ccal import ccal

mpl.rcParams['figure.figsize'] = (8, 5)
mpl.rcParams['figure.max_open_warning'] = 100

# %%
from ccal.ccal import bioinformatics

# %%
matplotlib inline

# %%
DATA_DIR = '/Users/kateme/discover/data/'
RESULT_DIR = '/Users/kateme/discover/results/'

# %% [markdown]
# # SimpleX Examples

# %% [markdown]
# In the Input of the Simplex app below, enter the path to simplex/test_data/test.gct. In the output write "test". Then run the cells below.

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"library_path":"/Users/kateme/ccal/","function_name":"read_gct","required_args":[{"label":".GCT file","arg_name":"filepath","value":"","description":"No description :("}],"description":"","default_args":[],"returns":[{"label":"Matrix","description":"No description :("}],"optional_args":[],"library_name":"ccal","label":"Read .GCT File"}'''))
task_view.create()

# %% [markdown]
# Above python converted the test.gct into a data frame and saved in the variable "test". By writing only "test" in the cell below, I'm asking python to show me whats stored in that variable, which is the test data frame. The font, shading, line thickness, and spacing of the data frames can be changed with .css.

# %%
test
# Out:
#                shbq051.shbq051  shbq052.shbq052  shbq053.shbq053  \
# IMAGE:45649               0.35             0.76             0.00
# IMAGE:1700310             0.10            -0.53            -0.39
# IMAGE:252515             -1.32            -0.84            -1.48
# IMAGE:780969             -0.02            -0.06             0.56
# IMAGE:488246             -0.56            -0.77            -0.57
# IMAGE:23869               0.32             0.06             0.21
# IMAGE:236059             -0.15            -0.16            -0.04
# IMAGE:299468             -0.39             0.47             0.84
# IMAGE:253507             -0.35            -0.96             1.58
# IMAGE:276805              0.50             1.15             0.66
# IMAGE:275173             -0.03             0.17             0.20
# IMAGE:1007833             0.27            -0.23            -0.50
# IMAGE:383528              0.00             0.00             0.00
# ...

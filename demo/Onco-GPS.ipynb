# %% [raw]
# /home/cyborg/simplex/test/data/A.gct

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"optional_args":[],"description":"","library_path":"/home/cyborg/ccal","library_name":"ccal","required_args":[{"arg_name":"filepath","value":"","label":".GCT file","description":"No description :("}],"returns":[{"label":"Matrix","description":"No description :("}],"function_name":"read_gct","default_args":[],"label":"Read .GCT File"}'''))
task_view.create()
# Out:
# Executing ...
# 	sys.path.insert(0, '/home/cyborg/ccal')
# 	from ccal import read_gct as function
# Planted a random seed: 20121020.
#
# 	Executing <function read_gct at 0x7f39c43b9b70>:
# 		filepath = '/home/cyborg/simplex/test/data/A.gct' (<class 'str'>)

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"optional_args":[],"description":"","library_path":"/home/cyborg/ccal","library_name":"ccal","required_args":[{"arg_name":"matrix","value":"","label":"Matrix","description":"No description :("},{"arg_name":"ks","value":"","label":"Numbers of Components","description":"No description :("}],"returns":[{"label":"NMF Result Dictionary","description":"No description :("},{"label":"Cophenetic Correlation Coefficients","description":"No description :("}],"function_name":"define_components","default_args":[{"arg_name":"n_clusterings","value":"30","label":"N Clusterings","description":"No description :("}],"label":"Define NMF Components"}'''))
task_view.create()
# Out:
# Executing ...
# 	sys.path.insert(0, '/home/cyborg/ccal')
# 	from ccal import define_components as function
#
# 	Executing <function define_components at 0x7f39c3f46158>:
# 		ks = '[8, 9, 10]' (<class 'list'>)
# 		matrix = A (<class 'pandas.core.frame.DataFrame'>)
# 		n_clusterings = '30' (<class 'int'>)

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"library_path":"/home/cyborg/ccal","required_args":[{"value":"","description":"No description :(","label":"Nmf Results","arg_name":"nmf_results"},{"value":"","description":"No description :(","label":"Number of Components","arg_name":"k"}],"optional_args":[],"description":"","returns":[{"description":"No description :(","label":"H Matrix"}],"function_name":"get_w_or_h_matrix","library_name":"ccal","default_args":[{"value":"h","description":"No description :(","label":"W or H","arg_name":"w_or_h"}],"label":"Get H Matrix"}'''))
task_view.create()
# Out:
# Executing ...
# 	sys.path.insert(0, '/home/cyborg/ccal')
# 	from ccal import get_w_or_h_matrix as function
#
# 	Executing <function get_w_or_h_matrix at 0x7f39c4110510>:
# 		k = '9' (<class 'int'>)
# 		nmf_results = nmf (<class 'dict'>)
# 		w_or_h = 'h' (<class 'str'>)

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"library_path":"/home/cyborg/ccal","required_args":[{"value":"","description":"No description :(","label":"H Matrix","arg_name":"matrix"},{"value":"","description":"No description :(","label":"Numbers of States","arg_name":"ks"}],"optional_args":[],"description":"","returns":[{"description":"No description :(","label":"Distance Matrix"},{"description":"No description :(","label":"Clusterings"},{"description":"No description :(","label":"Cophenetic Correlation Coefficients"}],"function_name":"define_states","library_name":"ccal","default_args":[],"label":"Define States"}'''))
task_view.create()
# Out:
# Executing ...
# 	sys.path.insert(0, '/home/cyborg/ccal')
# 	from ccal import define_states as function
#
# 	Executing <function define_states at 0x7f39c41106a8>:
# 		ks = '[7, 8, 9, 10, 11]' (<class 'list'>)
# 		matrix = H (<class 'pandas.core.frame.DataFrame'>)

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"library_path":"/home/cyborg/ccal","required_args":[{"value":"","description":"No description :(","label":"Clusterings","arg_name":"clusterings"},{"value":"","description":"No description :(","label":"Number of States","arg_name":"k"}],"optional_args":[],"description":"","returns":[{"description":"No description :(","label":"State Labels"}],"function_name":"get_state_labels","library_name":"ccal","default_args":[],"label":"Get State Labels"}'''))
task_view.create()
# Out:
# Executing ...
# 	sys.path.insert(0, '/home/cyborg/ccal')
# 	from ccal import get_state_labels as function
#
# 	Executing <function get_state_labels at 0x7f39c4110730>:
# 		clusterings = clusterings (<class 'pandas.core.frame.DataFrame'>)
# 		k = '8' (<class 'int'>)

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"library_path":"/home/cyborg/ccal","required_args":[{"value":"","description":"No description :(","label":"H Matrix","arg_name":"training_h"},{"value":"","description":"No description :(","label":"Sample State Labels","arg_name":"training_states"}],"optional_args":[],"description":"","returns":[],"function_name":"make_oncogps","library_name":"ccal","default_args":[],"label":"Make Onco-GPS"}'''))
task_view.create()
# Out:
# Executing ...
# 	sys.path.insert(0, '/home/cyborg/ccal')
# 	from ccal import make_oncogps as function
#
# 	Executing <function make_oncogps at 0x7f39c41107b8>:
# 		training_h = H (<class 'pandas.core.frame.DataFrame'>)
# 		training_states = state_labels (<class 'list'>)

# %% [raw]
# /home/cyborg/simplex/test/data/A.gct

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"required_args":[{"arg_name":"filepath","label":".GCT file","value":"","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci."}],"library_name":"ccal","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci.","function_name":"read_gct","optional_args":[],"default_args":[],"return_names":[{"label":"Matrix","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci."}],"library_path":"/home/cyborg/ccal/","label":"Read .GCT File"}'''))
task_view.create()
# Out:
# Executing a task ...
# 	sys.path.insert(0, '/home/cyborg/ccal/')
# Planted a random seed: 20121020.
# 	from ccal import read_gct as function
# Processing arguments ...
# 	filepath: /home/cyborg/simplex/test/data/A.gct ==> '/home/cyborg/simplex/test/data/A.gct' (<class 'str'>)
# 	Executing <function read_gct at 0x7f0e9d477d08> with:
# 		filepath='/home/cyborg/simplex/test/data/A.gct' (<class 'str'>)

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"required_args":[{"label":"Expression Matrix","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci.","value":"","arg_name":"matrix"},{"label":"Numbers of Components","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci.","value":"","arg_name":"ks"}],"return_names":[{"label":"NMF Result Dictionary","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci."},{"label":"Cophenetic Correlation Coefficients","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci."}],"optional_args":[],"library_path":"/home/cyborg/ccal/","function_name":"define_components","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci.","default_args":[],"library_name":"ccal","label":"Define NMF Components"}'''))
task_view.create()
# Out:
# Executing a task ...
# 	sys.path.insert(0, '/home/cyborg/ccal/')
# 	from ccal import define_components as function
# Processing arguments ...
# 	matrix: a_matrix ==> a_matrix (<class 'pandas.core.frame.DataFrame'>)
# 	ks: 8,9,10 ==> '[8, 9, 10]' (<class 'list'>)
# 	Executing <function define_components at 0x7f0e9d2442f0> with:
# 		ks='[8, 9, 10]' (<class 'list'>)
# 		matrix=a_matrix (<class 'pandas.core.frame.DataFrame'>)

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"required_args":[{"label":"NMF Results","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci.","value":"","arg_name":"nmf_results"},{"label":"Number of Components","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci.","value":"","arg_name":"k"}],"return_names":[{"label":"H Matrix","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci."}],"optional_args":[],"library_path":"/home/cyborg/ccal/","function_name":"get_w_or_h_matrix","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci.","default_args":[{"label":"w_or_h","description":"No description.","value":"h","arg_name":"w_or_h"}],"library_name":"ccal","label":"Get H Matrix"}'''))
task_view.create()
# Out:
# Executing a task ...
# 	sys.path.insert(0, '/home/cyborg/ccal/')
# 	from ccal import get_w_or_h_matrix as function
# Processing arguments ...
# 	k: 9 ==> '9' (<class 'int'>)
# 	w_or_h: h ==> 'h' (<class 'str'>)
# 	nmf_results: nmf_results ==> nmf_results (<class 'dict'>)
# 	Executing <function get_w_or_h_matrix at 0x7f0e9d2156a8> with:
# 		k='9' (<class 'int'>)
# 		nmf_results=nmf_results (<class 'dict'>)
# 		w_or_h='h' (<class 'str'>)

# %%
h_matrix
# Out:
#    A3KAW_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  \
# 0                                 12.593125
# 1                                  0.000000
# 2                                  0.000000
# 3                                 12.216558
# 4                                 32.072097
# 5                                 10.986941
# 6                                 11.568310
# 7                                125.871191
# 8                                  6.980370
#
#    A4FUK_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  \
# 0                                  9.405623
# 1                                  2.609427
# 2                                 17.387041
# 3                                 12.741991
# 4                                  1.934108
# 5                                 21.759908
# 6                                  0.505932
# 7                                132.286179
# 8                                  6.530518
#
#    ALLSIL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  \
# ...

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"required_args":[{"label":"H Matrix","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci.","value":"","arg_name":"matrix"},{"label":"Numbers of States","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci.","value":"","arg_name":"ks"}],"return_names":[{"label":"Distance Matrix","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci."},{"label":"Clusterings","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci."},{"label":"Cophenetic Correlation Coefficients","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci."}],"optional_args":[],"library_path":"/home/cyborg/ccal/","function_name":"define_states","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci.","default_args":[],"library_name":"ccal","label":"Define States"}'''))
task_view.create()
# Out:
# Executing a task ...
# 	sys.path.insert(0, '/home/cyborg/ccal/')
# 	from ccal import define_states as function
# Processing arguments ...
# 	matrix: h_matrix ==> h_matrix (<class 'pandas.core.frame.DataFrame'>)
# 	ks: 8, 9,10,11,12 ==> '[8, 9, 10, 11, 12]' (<class 'list'>)
# 	Executing <function define_states at 0x7f0e9d215840> with:
# 		ks='[8, 9, 10, 11, 12]' (<class 'list'>)
# 		matrix=h_matrix (<class 'pandas.core.frame.DataFrame'>)

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"required_args":[{"label":"Clusterings","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci.","value":"","arg_name":"clusterings"},{"label":"Number of States","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci.","value":"","arg_name":"k"}],"return_names":[{"label":"State Labels","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci."}],"optional_args":[],"library_path":"/home/cyborg/ccal/","function_name":"get_state_labels","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci.","default_args":[],"library_name":"ccal","label":"Get State Labels"}'''))
task_view.create()
# Out:
# Executing a task ...
# 	sys.path.insert(0, '/home/cyborg/ccal/')
# 	from ccal import get_state_labels as function
# Processing arguments ...
# 	clusterings: clusterings ==> clusterings (<class 'pandas.core.frame.DataFrame'>)
# 	k: 8 ==> '8' (<class 'int'>)
# 	Executing <function get_state_labels at 0x7f0e9d2158c8> with:
# 		clusterings=clusterings (<class 'pandas.core.frame.DataFrame'>)
# 		k='8' (<class 'int'>)

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"required_args":[{"label":"H Matrix","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci.","value":"","arg_name":"training_h"},{"label":"Sample State Labels","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci.","value":"","arg_name":"training_states"}],"return_names":[],"optional_args":[],"library_path":"/home/cyborg/ccal/","function_name":"make_oncogps_map","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci.","default_args":[],"library_name":"ccal","label":"Make Onco-GPS Map"}'''))
task_view.create()
# Out:
# Executing a task ...
# 	sys.path.insert(0, '/home/cyborg/ccal/')
# 	from ccal import make_oncogps_map as function
# Processing arguments ...
# 	training_h: h_matrix ==> h_matrix (<class 'pandas.core.frame.DataFrame'>)
# 	training_states: state_labels ==> state_labels (<class 'list'>)
# 	Executing <function make_oncogps_map at 0x7f0e9d215950> with:
# 		training_h=h_matrix (<class 'pandas.core.frame.DataFrame'>)
# 		training_states=state_labels (<class 'list'>)

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"library_path":"/home/cyborg/ccal/","library_name":"ccal","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci.","return_names":[],"default_args":[],"optional_args":[],"required_args":[{"value":"","label":"Matrix to be written as a .GCT","arg_name":"matrix","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci."},{"value":"","label":".GCT file","arg_name":"filepath","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci."}],"function_name":"write_gct","label":"Write .GCT File"}'''))
task_view.create()
# Out:
# Executing a task ...
# 	sys.path.insert(0, '/home/cyborg/ccal/')
# 	from ccal import write_gct as function
# Processing arguments ...
# 	matrix: h_matrix ==> h_matrix (<class 'pandas.core.frame.DataFrame'>)
# 	filepath: /home/cyborg/Desktop/H.gct ==> '/home/cyborg/Desktop/H.gct' (<class 'str'>)
# 	Executing <function write_gct at 0x7f0e9d477d90> with:
# 		filepath='/home/cyborg/Desktop/H.gct' (<class 'str'>)
# 		matrix=h_matrix (<class 'pandas.core.frame.DataFrame'>)

# %% [raw]
# /home/cyborg/simplex/test/data/A.gct

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"description":"","library_name":"ccal","optional_args":[],"library_path":"/home/cyborg/ccal","default_args":[],"function_name":"read_gct","required_args":[{"arg_name":"filepath","value":"","description":"No description :(","label":".GCT file"}],"returns":[{"description":"No description :(","label":"Matrix"}],"label":"Read .GCT File"}'''))
task_view.create()
# Out:
# Executing ...
# 	sys.path.insert(0, '/home/cyborg/ccal')
# 	from ccal import read_gct as function
#
# 	Executing <function read_gct at 0x7fb28be4a400>:
# 		filepath = '/home/cyborg/simplex/test/data/A.gct' (<class 'str'>)

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"description":"","library_name":"ccal","optional_args":[],"library_path":"/home/cyborg/ccal","default_args":[{"arg_name":"n_clusterings","value":"30","description":"No description :(","label":"N Clusterings"}],"function_name":"define_components","required_args":[{"arg_name":"matrix","value":"","description":"No description :(","label":"Matrix"},{"arg_name":"ks","value":"","description":"No description :(","label":"Numbers of Components"}],"returns":[{"description":"No description :(","label":"NMF Result Dictionary"},{"description":"No description :(","label":"Cophenetic Correlation Coefficients"}],"label":"Define NMF Components"}'''))
task_view.create()
# Out:
# Executing ...
# 	sys.path.insert(0, '/home/cyborg/ccal')
# 	from ccal import define_components as function
#
# 	Executing <function define_components at 0x7fb28be0b730>:
# 		ks = '[9, 10]' (<class 'list'>)
# 		matrix = A (<class 'pandas.core.frame.DataFrame'>)
# 		n_clusterings = '30' (<class 'int'>)

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"description":"","library_name":"ccal","optional_args":[],"library_path":"/home/cyborg/ccal","default_args":[{"arg_name":"w_or_h","value":"h","description":"No description :(","label":"W or H"}],"function_name":"get_w_or_h_matrix","required_args":[{"arg_name":"nmf_results","value":"","description":"No description :(","label":"Nmf Results"},{"arg_name":"k","value":"","description":"No description :(","label":"Number of Components"}],"returns":[{"description":"No description :(","label":"H Matrix"}],"label":"Extract H Matrix"}'''))
task_view.create()
# Out:
# Executing ...
# 	sys.path.insert(0, '/home/cyborg/ccal')
# 	from ccal import get_w_or_h_matrix as function
#
# 	Executing <function get_w_or_h_matrix at 0x7fb28f363048>:
# 		k = '9' (<class 'int'>)
# 		nmf_results = nmf (<class 'dict'>)
# 		w_or_h = 'h' (<class 'str'>)

# %%
H
# Out:
#    A3KAW_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  \
# 0                                 12.593125
# 1                                  0.000000
# 2                                  0.000000
# 3                                 12.216558
# 4                                 32.072097
# 5                                 10.986941
# 6                                 11.568310
# 7                                125.871191
# 8                                  6.980370
#
#    A4FUK_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  \
# 0                                  9.405623
# 1                                  2.609427
# 2                                 17.387041
# 3                                 12.741991
# 4                                  1.934108
# 5                                 21.759908
# 6                                  0.505932
# 7                                132.286179
# 8                                  6.530518
#
#    ALLSIL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  \
# ...

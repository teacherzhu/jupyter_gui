# %% [raw]
# /home/cyborg/data/grch/38/sequence/primary_assembly/Homo_sapiens.GRCh38.dna.primary_assembly.fa.gz

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"description":"","optional_args":[],"library_name":"cgal","returns":[{"description":"No description :(","label":"DNA Sequence"}],"function_name":"get_sequence","library_path":"/home/cyborg/cgal","default_args":[],"required_args":[{"description":"No description :(","label":"Filepath","arg_name":"filepath","value":""},{"description":"No description :(","label":"Chromosome","arg_name":"chromosome","value":""},{"description":"No description :(","label":"Start","arg_name":"start","value":""},{"description":"No description :(","label":"End","arg_name":"end","value":""}],"label":"Get DNA Sequence"}'''))
task_view.create()
# Out:
# Executing ...
# 	sys.path.insert(0, '/home/cyborg/cgal')
# 	from cgal import get_sequence as function
#
# 	Executing <function get_sequence at 0x7f04a5baf2f0>:
# 		chromosome = '1' (<class 'int'>)
# 		end = '15000' (<class 'int'>)
# 		filepath = '/home/cyborg/data/grch/38/sequence/primary_assembly/Homo_sapiens.GRCh38.dna.primary_assembly.fa.gz' (<class 'str'>)
# 		start = '11000' (<class 'int'>)
# samtools faidx /home/cyborg/data/grch/38/sequence/primary_assembly/Homo_sapiens.GRCh38.dna.primary_assembly.fa.gz 1:11000-15000
# ...

# %%
X
# Out:
# '...'

# %%
Y
# Out:
# '...'

# %%
X
# Out:
# '...'

# %%
# !AUTOEXEC
from simplex.taskmanager import TaskManager
import json, os, matplotlib

# %matplotlib inline

# load wrapper
config = json.loads('''{"version":"","library_path":"/Users/ckmah/ccal/","tasks":[{"library_name":"ccal","label":"Define Components","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci.","function_name":"define_components","required_args":[{"arg_name":"matrix","label":"Expression Matrix","description":"This is an argument description for Expression Matrix."},{"arg_name":"ks","label":"Numbers of Components","description":"This is an argument description for Number of Components."}],"optional_args":[{"arg_name":"n_clusterings","label":"Number of Consensus Clusterings","description":"This is an argument description for Number of Consensus Clusterings."}],"return_names":[{"label":"NMF Result Dictionary","description":"This is the description for the returned NMF Result Dictionary."},{"label":"Cophenetic Correlation Coefficients","description":"This is the description for the returned Cophentic Correlation Coefficients."}]}]}''')
task_manager = TaskManager(config, globals(), locals(), os.getcwd())

def set_globals():
    task_manager.global_n = globals()
    for name, value in task_manager.output.items():
        globals()[name] = value
        # exec('global {}'.format(name), globals())
        # exec('{} = value'.format(name))

# register callback
if (set_globals not in get_ipython().events.callbacks['post_run_cell']):
    get_ipython().events.register('post_execute', set_globals)

# make and show widget
task_view = task_manager.create_task_view(task_manager.tasks[0])
task_view.createPanel()
# Out:
# From /Users/ckmah/ccal/ importing define_components ...
# /Users/ckmah/anaconda3/envs/simplex/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# ...
# ================= Computational Cancer Analysis Library (CCAL) =================
# ...
# Planted a random seed: 20121020.
# arg-key: matrix; arg-val: /Users/ckmah/Documents/simplex/test_data/A.gct
# - /Users/ckmah/Documents/simplex/test_data/A.gct converted to <class 'str'>
# arg-key: ks; arg-val: 9
# - 9 converted to <class 'int'>
# arg-key: n_clusterings; arg-val: 10
# - 10 converted to <class 'int'>
# ...

# %%
# !AUTOEXEC
from simplex.taskmanager import TaskManager
import json, os, matplotlib

# %matplotlib inline

# load wrapper
config = json.loads('''{"version":"","library_path":"/Users/ckmah/ccal/","tasks":[{"library_name":"ccal","label":"Get H Matrix","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci.","function_name":"get_w_or_h_matrix","default_args":[{"arg_name":"w_or_h","value":"h"}],"required_args":[{"arg_name":"nmf_results","label":"NMF Results","description":"This is an argument description for NMF Results."},{"arg_name":"k","label":"Number of Components","description":"This is an argument description for Number of Components."}],"return_names":[{"label":"H Matrix","description":"This is the description for the returned Cophentic Correlation Coefficients."}]}]}''')
task_manager = TaskManager(config, globals(), locals(), os.getcwd())

def set_globals():
    task_manager.global_n = globals()
    for name, value in task_manager.output.items():
        globals()[name] = value
        # exec('global {}'.format(name), globals())
        # exec('{} = value'.format(name))

# register callback
if (set_globals not in get_ipython().events.callbacks['post_run_cell']):
    get_ipython().events.register('post_execute', set_globals)

# make and show widget
task_view = task_manager.create_task_view(task_manager.tasks[0])
task_view.createPanel()
# Out:
# From /Users/ckmah/ccal/ importing get_w_or_h_matrix ...
# arg-key: k; arg-val: 9
# - 9 converted to <class 'int'>
# arg-key: w_or_h; arg-val: h
# - h converted to <class 'str'>
# arg-key: nmf_results; arg-val: nmf_results
# + nmf_results in globals()
# RETURN NAMES LENGTH:  ['h_matrix']

# %%
# !AUTOEXEC
from simplex.taskmanager import TaskManager
import json, os, matplotlib

# %matplotlib inline

# load wrapper
config = json.loads('''{"version":"","library_path":"/Users/ckmah/ccal/","tasks":[{"library_name":"ccal","label":"Define States","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci.","function_name":"define_states","required_args":[{"arg_name":"matrix","label":"H Matrix","description":"This is an argument description for H Matrix."},{"arg_name":"ks","label":"Numbers of States","description":"This is an argument description for Number of States."}],"return_names":[{"label":"Distance Matrix","description":"This is the description for returned Distance Matrix."},{"label":"Clusterings","description":"This is the description for the returned Clusterings."},{"label":"Cophenetic Correlation Coefficients","description":"This is the description for the returned Cophentic Correlation Coefficients."}]}]}''')
task_manager = TaskManager(config, globals(), locals(), os.getcwd())

def set_globals():
    task_manager.global_n = globals()
    for name, value in task_manager.output.items():
        globals()[name] = value
        # exec('global {}'.format(name), globals())
        # exec('{} = value'.format(name))

# register callback
if (set_globals not in get_ipython().events.callbacks['post_run_cell']):
    get_ipython().events.register('post_execute', set_globals)

# make and show widget
task_view = task_manager.create_task_view(task_manager.tasks[0])
task_view.createPanel()
# Out:
# From /Users/ckmah/ccal/ importing define_states ...
# arg-key: matrix; arg-val: h_matrix
# + h_matrix in globals()
# arg-key: ks; arg-val: 9
# - 9 converted to <class 'int'>
# <170146> Computing distances between samples, making a distance matrix ...
# <170146> Computing associations (axis=0) between matrices (0/166) ...
# <170146> Computing associations (axis=0) between matrices (1/166) ...
# <170146> Computing associations (axis=0) between matrices (2/166) ...
# <170147> Computing associations (axis=0) between matrices (3/166) ...
# <170147> Computing associations (axis=0) between matrices (4/166) ...
# <170148> Computing associations (axis=0) between matrices (5/166) ...
# <170148> Computing associations (axis=0) between matrices (6/166) ...
# <170149> Computing associations (axis=0) between matrices (7/166) ...
# <170149> Computing associations (axis=0) between matrices (8/166) ...
# <170149> Computing associations (axis=0) between matrices (9/166) ...
# ...

# %%
state_labels = clusterings.ix[9, :]
type(state_labels)
# Out:
# pandas.core.series.Series

# %%
# !AUTOEXEC
from simplex.taskmanager import TaskManager
import json, os, matplotlib

# %matplotlib inline

# load wrapper
config = json.loads('''{"version":"","library_path":"/Users/ckmah/ccal/","tasks":[{"library_name":"ccal","label":"Make Onco-GPS Map","description":"Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eos, eligendi? Eaque modi reprehenderit sequi, nulla amet magni inventore id fugit laborum ducimus nam, tempora incidunt quos, sapiente labore ratione adipisci.","function_name":"make_oncogps_map","required_args":[{"arg_name":"training_h","label":"H Matrix","description":"This is an argument description for H Matrix."},{"arg_name":"training_states","label":"Sample State Labels","description":"This is an argument description for Sample State Labels."}],"return_names":[]}]}''')
task_manager = TaskManager(config, globals(), locals(), os.getcwd())

def set_globals():
    task_manager.global_n = globals()
    for name, value in task_manager.output.items():
        globals()[name] = value
        # exec('global {}'.format(name), globals())
        # exec('{} = value'.format(name))

# register callback
if (set_globals not in get_ipython().events.callbacks['post_run_cell']):
    get_ipython().events.register('post_execute', set_globals)

# make and show widget
task_view = task_manager.create_task_view(task_manager.tasks[0])
task_view.createPanel()
